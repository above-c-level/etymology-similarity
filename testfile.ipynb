# %%
import bz2
import networkx as nx
import numpy as np
import os
import time

from typing import Tuple, List

INDEX = 'dumps/enwiktionary-latest-pages-articles-multistream-index.txt.bz2'
ARTICLES = 'dumps/enwiktionary-latest-pages-articles-multistream.xml.bz2'


def split_index(index_string: str) -> Tuple[int, int, str]:
    """
    Split an index string into its components.

    Parameters
    ----------
    index_string : str
        A string containing the byte offset, article ID, and title of an article.

    Returns
    -------
    Tuple[int, int, str]
        A tuple containing the byte offset, article ID, and title of the article.
    """
    parts = index_string.split(':')
    byte_offset = int(parts[0])
    article_id = int(parts[1])
    title = parts[2].strip()
    return byte_offset, article_id, title


def get_article(index_string: str) -> str:
    """
    Retrieve the content of an article given its index string.

    Parameters
    ----------
    index_string : str
        A string containing the byte offset, article ID, and title of an article.

    Returns
    -------
    str
        The content of the article, unprocessed.
    """
    decompressor = bz2.BZ2Decompressor()
    byte_offset, _, title = split_index(index_string)

    with open(ARTICLES, 'rb') as f:
        f.seek(byte_offset)
        decompressed_data = b''

        while True:
            chunk = f.read(1024)
            if not chunk:
                break
            decompressed_data += decompressor.decompress(chunk)
            if b'</page>' in decompressed_data:
                break

    # Convert bytes to string after decompression
    article = decompressed_data.decode('utf-8', errors='replace')

    # Extract the specific article content from the decompressed data
    end_tag = f'</page>'
    start_index = article.find(f'<title>{title}</title>')
    end_index = article.find(end_tag, start_index) + len(end_tag)

    if start_index != -1 and end_index != -1:
        # back up a bit for start_index to include the stuff before the title,
        # which is 11 characters (len('<page>') + 4 spaces + 1 newline)
        return article[start_index - 11:end_index]
    else:
        return "Article not found or incomplete."

# %%
def split_article(article: str) -> List[str]:
    """
    Splits an article up, grouping by language sections.

    Parameters
    ----------
    article : str
        The content of an article.

    Returns
    -------
    List[str]
        A list of strings, each containing the content of a language section.
    """
    return []

# %%
start = time.perf_counter()
with bz2.open(INDEX, 'rt', encoding='utf-8') as f:
    indices = f.readlines()
end = time.perf_counter()
print(f'Loaded {len(indices)} indices in {end - start:.2f} seconds.')
# Out:
# Loaded 9292639 indices in 15.08 seconds.

# %%
import re
import random
test_index = 22964
article = get_article(indices[test_index])
print(article)
# Out:
# <page>
#     <title>ta</title>
#     <ns>0</ns>
#     <id>26555</id>
#     <revision>
#       <id>80102692</id>
#       <parentid>79640642</parentid>
#       <timestamp>2024-06-03T03:25:47Z</timestamp>
#       <contributor>
#         <username>WingerBot</username>
#         <id>2024159</id>
#       </contributor>
#       <minor />
#       <comment>replace &lt;* {{audio|vi|LL-Q9199 (vie)-Penn Zero MSSJ-ta.wav|a=Hà Nội}}&gt; with &lt;* {{audio|vi|LL-Q9199 (vie)-Penn Zero MSSJ-ta.wav|a=Hanoi}}&gt; (clean up audio captions)</comment>
#       <origin>80102692</origin>
#       <model>wikitext</model>
#       <format>text/x-wiki</format>
#       <text bytes="53250" sha1="tjcuvgg9n8jkk100f7u44nzwjm08w13" xml:space="preserve">{{also|Appendix:Variations of &quot;ta&quot;}}
# ==Translingual==
#
# ===Symbol===
# {{mul-symbol}}
#
# # {{ISO 639|1}}
#
# ==English==
#
# ===Etymology 1===
# {{unc|en}}, but possibly young child's pronunciation of {{m-lite|en|thanks}}&lt;ref&gt;{{R:OED Online|code=196719|date=1989}}&lt;/ref&gt;&lt;ref&gt;&quot;[https://en.oxforddictionaries.com/definition/ta?locale=en ta]&quot; in Oxford Living Dictionaries&lt;/ref&gt; or an acronym for 'thanks a lot'.
#
# Alternatively, derived from {{bor-lite|en|da|tak}}, from {{der-lite|en|non|þǫkk}}, from {{der-lite|en|gem-pro|sc=Latn|*þankō}}, {{m-lite|gem-pro|sc=Latn|*þankaz}}.
#
# ====Alternative forms====
# * {{l-lite|en|taa}}
#
# ====Pronunciation====
# * {{IPA-lite|en|/tɑː/|[tʰɑː]}}
# * {{audio|en|en-au-ta.ogg|a=AU}}
# * {{rhymes-lite|en|ɑː|s=1}}
#
# ====Interjection====
# {{en-interj}}
#
# # {{lb|en|colloquial|chiefly|Commonwealth}} [[thanks|Thanks]].
# #: {{ux-lite|en|'''Ta''' for the cup of tea.}}
# # {{lb|en|Canada|baby talk}} [[give]] (imperative)
# #: {{ux-lite|en|Mommy needs the bottle back. '''Ta'''!}}
#
# =====Usage notes=====
# The expression ''[[ta ta]]'' differs, meaning ''[[goodbye]]''.
#
# =====Translations=====
# {{trans-see|thanks}}
#
# =====See also=====
# * {{l-lite|en|ta everso}}
# * {{l-lite|en|ta muchly}}
#
# ===Etymology 2===
#
# ====Pronunciation====
# * {{IPA-lite|en|/tə/}}
#
# ====Preposition====
# {{en-preposition}}
#
# # {{pronunciation spelling of|en|to|nodot=1}}'', representing the standard unstressed pronunciation before consonants.''
#
# ===Etymology 3===
# Altered from ''[[si]]'' in the 19th century to prevent having two notes of the musical scale starting with the same letter, to become ''[[ti]]''. vowel changed to 'a' to signify a flattened note.
#
# ====Pronunciation====
# * {{IPA-lite|en|/tɑː/}}
# * {{audio|en|en-au-ta.ogg|a=AU}}
# * {{rhymes-lite|en|ɑː|s=1}}
#
# ====Noun====
# {{en-noun|-}}
#
# # {{lb|en|music}} In [[solfège]], the lowered seventh note of a major scale (the note [[B-flat]] in the [[fixed-do]] system): [[te]].
# #: {{syn|en|te|B-flat|li}}
#
# ===See also===
# {{col2|en|pok-ta-pok|ta-da|Yah-ta-hey}}
#
# ===References===
# {{reflist}}
#
# ===Anagrams===
# * {{anagrams|en|a=at|'at|A-T|A/T|AT|at|at-}}
#
# [[Category:English two-letter words]]
#
# ==Abenaki==
#
# ===Conjunction===
# {{head-lite|abe|conjunctions}}
#
# # [[and]]
#
# ==Afar==
#
# ===Pronunciation===
# * {{aa-IPA|tá}}
#
# ===Determiner===
# {{head-lite|aa|determiners|head=tá|cat2=demonstrative determiners}}
#
# # [[this]], [[these]] (feminine)
#
# ====Derived terms====
# {{col4|aa
# |tákke}}
#
# ====See also====
# {{aa-demonstrative determiners}}
#
# ===References===
# * {{R:aa:Parker:1985|+}}
# * {{R:aa:Hassan Kamil:2015}}
#
# ==Aghu Tharrnggala==
#
# ===Verb===
# {{head-lite|gtu|verbs}}
#
# # [[see]]
#
# ===Further reading===
# * Barry Alpher, ''Connecting Thaypanic'', in ''Land and Language in Cape York Peninsula and the Gulf Country'', edited by Jean-Christophe Verstraete, Diane Hafner
#
# ==Ama==
#
# ===Pronunciation===
# * {{IPA-lite|amm|/ta/}}
#
# ===Noun===
# {{head-lite|amm|nouns}}
#
# # [[fire]]
#
# ==Angloromani==
#
# ===Alternative forms===
# * {{alter|rme|da|te|ti}}
#
# ===Etymology===
# From {{inh-lite|rme|rom|thaj}}.
#
# ===Pronunciation===
# * {{IPA-lite|rme|[ˈtʰə]}}
#
# ===Conjunction===
# {{head-lite|rme|conjunctions}}
#
# # [[and]]
#
# ===References===
# * {{R:Angloromani Dictionary|2=6}}
#
# ==Aragonese==
# {{alternative form of|an|enta}}
#
# ===Etymology===
# Maybe borrowed from {{cog|oc|entà}}, used only in [[Gascon]].
#
# ===Preposition===
# {{head|an|preposition}}
#
# # [[toward]], [[towards]]
# #: {{uxi|an|'''Ta''' la dreta ye la botiga de Francho.|To the right is Francho's shop.}}
# # {{alternative form of|an|pa}} (in [[benasqués]] and [[chistavín]])
#
# ==Aromanian==
#
# ===Alternative forms===
# * {{l-lite|rup|a ta}}
# * {{l-lite|rup|tauã|(a) tauã}}
#
# ===Etymology===
# From {{inh-lite|rup|VL.||*ta}}, from {{inh-lite|rup|la|tua}}, feminine of {{m-lite|la|tuus}}. Compare {{cog-lite|ro|ta}}.
#
# ===Pronoun===
# {{head-lite|rup|pronouns|cat2=possessive pronouns|g=f|masculine|tãu|feminine plural|tali|or|tale|masculine plural|tãi}}
#
# # {{inflection of|rup|tãu||f|s|t=your}}
#
# ==Asturian==
#
# ===Verb===
# {{head|ast|verb form}}
#
# # {{inflection of|ast|tar||3|s|pres|indc}}
#
# ==Azerbaijani==
#
# ===Etymology===
# From {{bor-lite|az|fa|sc=fa-Arab|تا}}.
#
# ===Particle===
# {{head-lite|az|particles}}
#
# # [[all the way]] {{n-g-lite|(adds emphasis to the measurement of a physical or temporal distance; coupled with {{m-lite|az|kimi||until}}, {{m-lite|az|qədər||until}}, {{m-lite|az|-dək||until}} or {{m-lite|az|-cən||until}})}}
# #: {{uxi|az|[[dəniz|Dəniz]] [[qıraq|qırağına]] [[kimi]] [[qaçmaq|qaçdı]].|S/he ran till the seaside.}}
# #: {{uxi|az|'''Ta''' [[dəniz]] [[qıraq|qırağına]] [[kimi]] [[qaçmaq|qaçdı]].|S/he ran '''all the way''' till the seaside.|q=the longness emphasized}}
# #: {{uxi|az|[[səni|Səni]] [[görmək]] [[üçün]] '''ta''' [[buraya]][[-cən|can]] [[yol]] [[gəlmək|gəldim]].|I came a long way '''all the way''' here to see you.}}
# #: {{uxi|az|'''ta''' [[indi|indiyə]] [[qədər]] [[davam etmək|davam edən]] [[dava]]|a conflict continuing '''all the way''' until now}}
#
# ===Further reading===
# * {{R:az:Obastan}}
#
# ==Basque==
#
# ===Pronunciation===
# {{eu-pr|+&lt;audio:LL-Q8752 (eus)-Xabier Cañas-ta.wav&gt;}}
#
# ===Conjunction===
# {{head-lite|eu|conjunctions}}
#
# # {{alternative form of|eu|eta|t=and}}
#
# ===Further reading===
# * {{R:OEH}}
#
# ==Bassa==
#
# ===Pronunciation===
# * {{IPA-lite|bsq|[tʰa]}}
#
# ===Noun===
# {{head-lite|bsq|nouns}}
#
# # [[tip]] {{gloss|extremity}}
#
# ===References===
# * 2007. [http://archive.phonetics.ucla.edu/Language/BSQ/bsq.html The UCLA Phonetics Lab Archive]. Los Angeles, CA: UCLA Department of Linguistics.
#
# ==Bikol Central==
#
# ===Etymology 1===
# {{inh+|bcl|map-pro|*ta}}.
#
# ====Pronunciation====
# * {{bcl-IPA}}
#
# ====Pronoun====
# {{bcl-head|pronoun|tá|b=+}}
#
# # by [[us]], of [[us]]  (including the person spoken to)
# #: {{ux|bcl|Linigan '''ta''' an kuwarto mo.|Let's (Let '''us''') clean your room.}}
# # [[our]]
# #: {{ux|bcl|Mga pirang lakaw sana an harong '''ta'''.|'''Our''' house is just a few walks away.}}
#
# =====Synonyms=====
# * {{l|bcl|niyato}}
#
# ===Etymology 2===
# {{inh+|bcl|phi-pro|*taq}}.
#
# ====Pronunciation====
# * {{bcl-IPA|tà}}
#
# ====Conjunction====
# {{bcl-head|conjunction|tà|b=+}}
#
# # [[because]]
# #: {{syn|bcl|huli|dahil|porke}}
# #: {{ux|bcl|Nag(p)uli na sana kami, '''ta''' banggi na.|We just went home '''because''' it's already nighttime.}}
#
# =====See also=====
# {{col3|bcl|huli ta|tano}}
#
# ==Cebuano==
#
# ===Pronunciation===
# * {{ceb-IPA}}
#
# ===Pronoun===
# {{ceb-head|pronoun|b=+}}
#
# # [[we]], [[us]] (1st personal plural inclusive short absolutive form)
#
# ====See also====
# {{ceb-personal pronouns}}
#
# ==Central Huasteca Nahuatl==
#
# ===Pronoun===
# {{head-lite|nch|pronouns}}
#
# # [[you]]
#
# ==Chamorro==
#
# ===Etymology===
# From {{inh-lite|ch|poz-pro|sc=Latn|*(i-)kita}}, from {{inh-lite|ch|map-pro|sc=Latn|*(i-)kita}}. {{doublet|ch|hit}}.
#
# ===Pronunciation===
# * {{IPA-lite|ch|/tæ/}}
#
# ===Pronoun===
# {{head|ch|pronoun|cat2=personal pronouns}}
#
# # [[we]] {{qualifier|inclusive}}
#
# ====Usage notes====
# * '''ta''' is used solely as a subject of a [[transitive verb]], while {{l-lite|ch|hit}} is used either as a subject of an [[intransitive verb]] or an object of a [[transitive verb]].
#
# ====See also====
# {{ch-personal pronouns}}
#
# ====References====
# * {{R:ch:Topping:1973}}
#
# ==Chavacano==
#
# ===Etymology===
# From {{der-lite|cbk|es|está}}.
#
# ===Adverb===
# {{head-lite|cbk|adverbs}}
#
# # {{n-g-lite|Indicates the [[present tense]].}}
#
# ==Chinese==
#
# ===Pronoun===
# {{head-lite|zh|pronouns}}
#
# # {{alt form|zh|TA|tr=tā}}
#
# ==Czech==
#
# ===Pronunciation===
# * {{cs-IPA}}
# * {{audio|cs|Cs-ta.ogg}}
#
# ===Pronoun===
# {{head|cs|pronoun form}}
#
# # {{infl of|cs|ten||nom|f|s|;|nom//acc|n|p}}
#
# ===Further reading===
# * {{R:cs:PSJC}}
# * {{R:cs:SSJC}}
# * {{R:cs:IJP}}
#
# ==Dama (Sierra Leone)==
#
# ===Etymology===
# Cognate with {{cog-lite|vai|sc=Vaii|ꕚꕌ|tr=táá}}.
#
# ===Verb===
# {{head-lite|dmn-dam|verbs}}
#
# # [[go]]
#
# ===References===
# * {{R:dmn-dam:Dalby}}
#
# ==Danish==
#
# ===Verb===
# {{head-lite|da|verbs}}
#
# # {{clipping of|da|tage}}
#
# ==Drung==
#
# ===Etymology===
# From {{inh-lite|duu|sit-pro|*rta}}.
#
# ===Noun===
# {{head-lite|duu|nouns}}
#
# # [[horse]]
#
# ===References===
# * {{R:duu:Perlin:2019}}
#
# ==Dupaningan Agta==
#
# ===Conjunction===
# {{head-lite|duo|conjunctions}}
#
# # [[because]]
#
# ==Eastern Huasteca Nahuatl==
#
# ===Pronoun===
# {{head-lite|nhe|pronouns}}
#
# # {{n-g-lite|second person}}; [[you]] (singular)\
#
# ===See also===
# * {{l-lite|nhe|taha}}
#
# ==Estonian==
#
# ===Etymology===
# {{abbrev|et|tema}}, from {{inh-lite|et|urj-fin-pro|*tämä}}, from {{inh-lite|et|urj-pro|sc=Latn|*tä}}. Cognate with {{cog-lite|fi|tämä}} and {{cog-lite|se|dát}}.
#
# ===Pronunciation===
# * {{IPA-lite|et|/tɑ/}}
#
# ===Pronoun===
# {{head|et|pronoun|genitive|ta|partitive|teda|long form|tema}}
#
# # [[he]]/[[she]] {{gl|3rd person singular animate personal pronoun}}
#
# ====Usage notes====
# * Used unstressed in a sentence; when the pronoun is stressed, {{m-lite|et|tema}} is used.
#
# ====Declension====
# {{et-decl-ppron|ta}}
#
# ====See also====
# {{et-personal pronouns}}
#
# ===Further reading===
# * {{R:EKSS}}
# * {{R:et:EÕS}}
# * {{R:Sõnaveeb}}
#
# ==Ewe==
#
# ===Noun===
# {{head-lite|ee|nouns}}
#
# # [[chapter]]
# # [[head]] (part of the body)
#
# ===Verb===
# {{head-lite|ee|verbs}}
#
# # to [[castrate]]
# # to [[crawl]] (to move slowly on hands and knees)
# # to [[neuter]]
#
# [[Category:ee:Anatomy]]
#
# ==Faroese==
#
# ===Pronunciation===
# * {{IPA-lite|fo|[tɛa]}}
#
# ===Pronoun===
# {{head|fo|pronoun|demonstrative}}
#
# # [[that]], {{inflection of|fo|tann||acc|s|f|form}}
# #: {{ux-lite|fo|'''ta''' ferðina|translation=at that (certain) time}}
#
# ====Declension====
# {{fo-decl-dem-pron-tann}}
#
# ==French==
#
# ===Etymology===
# From {{inh-lite|fr|fro|ta}}, from {{inh-lite|fr|la|tua}}, feminine of {{m-lite|la|tuus}}.
#
# ===Pronunciation===
# * {{fr-IPA}}
# * {{audio|fr|Fr-ta.ogg}}
#
# ===Determiner===
# {{head|fr|determiner|cat2=possessive determiners|g=f}}
#
# # [[your]]
# #: {{ux-lite|fr|Quel âge a '''ta''' grand-mère ?|How old is '''your''' grandmother?}}
#
# ====Related terms====
# {{French possessive adjectives}}
#
# ===Further reading===
# * {{R:fr:TLFi}}
#
# ==Greenlandic==
#
# ===Pronunciation===
# * {{kl-IPA}}
#
# ===Interjection===
# {{head|kl|interjection}}
#
# # {{alt sp|kl|taa}}
#
# ====References====
# * [https://web.archive.org/web/20201108093110/http://www.ilinniusiorfik.gl/oqaatsit/daka DAKA]
# * Lorentzen, S. Den grønlandske ordbog, at [https://web.archive.org/web/20201112003144/https://oqaasileriffik.gl/resources/greenlandic-english-dictionary/ oqaasileriffik.gl]
#
# ==Haitian Creole==
#
# ===Pronunciation===
# * {{IPA|ht|/ta/}}
#
# ===Etymology 1===
# From {{der|ht|fr|tard||late}}.
#
# ====Adjective====
# {{head-lite|ht|adjectives}}
#
# # [[late]]
#
# ===Etymology 2===
#
# ====Adverb====
# {{head-lite|ht|adverbs}}
#
# # {{n-g-lite|Indicates the [[conditional mood]]}}.
# # Indicating conditionality or potentiality in order to express a sense of politeness, tentativeness, indirectness, hesitancy, uncertainty, etc.
#
# ==Hawaiian==
#
# ===Article===
# {{head-lite|haw|articles}}
#
# # {{alt form|haw|ka|from=Niihau|t=the}}
# #: {{ux-lite|haw|'''Ta''' matua.|t='''The''' parent.}}
#
# ==Ido==
#
# ===Pronunciation===
# * {{IPA-lite|io|/ta/}}
#
# ===Pronoun===
# {{head|io|pronoun|plural|ti}}
#
# # {{alternative form of|io|ita||that person, that thing}}
# #: {{ux-lite|io|'''Ta''' esas plu forta, ma ca plu bela.|'''That person''' is stronger, but this person is prettier.|inline=1}}
#
# ===Determiner===
# {{head-lite|io|determiners}}
#
# # {{alternative form of|io|ita}}
# #: {{ux-lite|io|'''Ta''' kamizo esas verda.|'''That''' shirt is green.|inline=1}}
#
# [[Category:Ido correlatives]]
# [[Category:Ido demonstrative determiners]]
# [[Category:Ido demonstrative pronouns]]
#
# ==Indo-Portuguese==
#
# ===Etymology===
# From {{der-lite|idb|pt|está||is}}, third-person singular present indicative of {{m-lite|pt|estar||to be}}.
#
# ===Particle===
# {{head-lite|idb|particles}}
#
# # {{n-g-lite|forms the progressive aspect}}
# #* {{quote-text|idb|year=1883|author=Hugo Schuchardt|title=Kreolische Studien|volume=3
# |passage={{...}}, que da-cá su quião que '''ta''' pertencê a êll.
# |translation={{...}}, to give him his share which belongs (literally: '''is''' belonging) to him.}}
#
# ==Japanese==
#
# ===Romanization===
# {{ja-romaji}}
#
# # {{Latn-def|ja|syllable|た|タ|ta}}
#
# ==Kaingang==
#
# ===Noun===
# {{head-lite|kgp|nouns}}
#
# # [[rain]]
#
# ==Karelian==
# {{krl-regional|ta|da}}
#
# ===Etymology===
# Borrowed from {{bor|krl|ru|да}}.
#
# ===Pronunciation===
# * {{IPA|krl|/ˈtɑ/}}
# * {{hyph|krl|ta}}
#
# ===Conjunction===
# {{head|krl|conjunction}}
#
# # {{lb|krl|North Karelian}} [[and]]
#
# ===References===
# * {{R:krl:KKS|ta}}
# * {{R:krl:Zaykov:2015|и}}
#
# ==Kikuyu==
#
# ===Particle===
# {{head|ki|particle|followed by noun or pronoun}}
#
# # [[like]], [[as]]&lt;ref&gt;{{R:Benson1964|entry=ta&lt;sup&gt;1&lt;/sup&gt;|p=422}}&lt;/ref&gt;
#
# ===References===
# {{reflist}}
#
# ==Kuku-Thaypan==
#
# ===Verb===
# {{head-lite|typ|verbs}}
#
# # [[see]]
#
# ===Further reading===
# * Barry Alpher, ''Connecting Thaypanic'', in ''Land and Language in Cape York Peninsula and the Gulf Country'', edited by Jean-Christophe Verstraete, Diane Hafner
#
# ==Lala (South Africa)==
#
# ===Etymology===
# From {{inh-lite|bnt-lal|bnt-pro|sc=Latn|*-jìja}}.
#
# ===Verb===
# {{head|bnt-lal|verb|head=-ta}}
#
# # to [[come]]
#
# ==Lithuanian==
#
# ===Pronoun===
# {{head|lt|pronoun form}}
#
# # {{infl of|lt|tas||nom//ins|f|s}}
#
# ==Livonian==
#
# ===Alternative forms===
# * {{l-lite|liv|tämā}}
#
# ===Etymology===
# From {{derived|liv|urj-pro|*tä}}. Compare {{cog-lite|et|tema}}.
#
# ===Pronoun===
# {{head-lite|liv|pronouns}}
#
# # [[he]], [[she]]; {{n-g-lite|third-person pronoun, referring to someone other than the speaker or addressee}}
#
# ====Declension====
# {{liv-noun-manual
# |nom=tämā
# |gen=täm
# |part=tǟnda
# |dat=tämmõn
# |ins=tämkõks
# |ill=tämmõ
# |in=tämsõ
# |el=tämstõ
# |nom-pl=ne
# |gen-pl=nänt
# |part-pl=nēḑi
# |dat-pl=näntõn
# |ins-pl=näntkõks
# |ill-pl=nēži
# |in-pl=nēši
# |el-pl=nēšti
# |alt-nom=ta
# |alt-dat-pl=tän
# |alt-ill=tämmõz|npc=1}}
#
# ====See also====
# * {{l-lite|liv|minā}}, {{l-lite|liv|ma}}
# * {{l-lite|liv|sinā}}, {{l-lite|liv|sa}}
#
# ===References===
# {{R:liv:LVVK}}
#
# ==Lower Sorbian==
#
# ===Pronunciation===
# * {{IPA-lite|dsb|[ta]}}
#
# ===Determiner===
# {{head-lite|dsb|determiner forms}}
#
# # {{inflection of|dsb|ten||nom|f|s}}
#
# ==Maltese==
#
# ===Pronunciation===
# * {{IPA-lite|mt|/taː/}}
# * {{homophones|mt|ta'|qq1=general|taha|qq2=except nonstandard}}
#
# ===Etymology 1===
# {{mt-root|għ-t-j|sense=giving}}
# From {{inh-lite|mt|ar|sc=Arab|أعطى|أَعْطَى|tr=ʔaʕṭā|to give}}.
#
# ====Verb====
# {{mt-verb|jagħti|pp=mogħti|vn=għoti|vn2=għati}}
#
# # to [[give]]
# #: {{ux|mt|'''Tani''' l-flus.|t=He '''gave''' me money.}}
# # to [[undertake]], to [[conduct]]
# # to [[fight]]
# #: {{ux|mt|Qabdu '''jagħtu'''.|t=They started to '''fight'''.}}
# # to [[beat]], to [[strike]], to [[hit]]
# #: {{ux|mt|'''Tawh''' sakemm qatluh.|t=They '''beat''' him until they killed him.}}
# # to [[apply]]
# # to [[take place]]
# # to [[describe]]
# # {{lb|mt|usually with the verb {{m|mt|kell}}}} to [[owe]] (money)
# #: {{ux|mt|Kemm għandi '''nagħtik'''?|t=How much do I '''owe''' you?}}
# # {{lb|mt|with the pronominal suffix {{m|mt|-ha}}}} to become [[addicted]] {{+preo|mt|għal}}
# #: {{uxi|mt|'''Ta'''ha għan-nisa|t='''He is taken''' to women}}
#
# =====Usage notes=====
# * As in Arabic, this verb has [[ditransitive]] construction. Thus for “I gave her the money” one says {{m-lite|mt||tajtha l-flus}}, rather than the perhaps expected {{m-lite|mt||*tajtilha l-flus}}.
#
# =====Conjugation=====
# {{mt-conj/ta}}
#
# =====Derived terms=====
# * {{l-lite|mt|ngħata}}
#
# ===Etymology 2===
# From {{m-lite|mt|jaf|taf|you know}}.
#
# ====Interjection====
# {{head|mt|interjection}}
#
# # {{n-g-lite|Postpositioned after a statement, used for minor emphasis.}}
# #: {{ux-lite|mt|Din hija ħaġa importanti, '''ta''', tinsihiex.|This is important, '''you know''', don’t forget it.}}
#
# ==Mandarin==
#
# ===Romanization===
# {{cmn-pinyin}}
#
# # {{nonstandard spelling of|cmn|sc=Latn|tā}}
# # {{nonstandard spelling of|cmn|sc=Latn|tá}}
# # {{nonstandard spelling of|cmn|sc=Latn|tǎ}}
# # {{nonstandard spelling of|cmn|sc=Latn|tà}}
#
# ====Usage notes====
# * {{cmn-toneless-note}}
#
# ===See also===
# * {{l-lite|zh|TA}}
#
# ==Manx==
#
# ===Alternative forms===
# * {{alter|gv|t’||apocopic}}
#
# ===Etymology===
# {{root|gv|ine-pro|*steh₂-}}
# From {{inh-lite|gv|sga|attá|at·tá}}, from {{inh|gv|cel-pro|*[[ad-]][[tāyeti]]}} (compare {{cog-lite|cy|taw||there is}}), from {{der-lite|gv|ine-pro|sc=Latn|*steh₂-||stand}}.
#
# ===Verb===
# {{head-lite|gv|verb forms}}
#
# # {{inflection of|gv|bee||pres|indc|independent}}
#
# ====Derived terms====
# {{col4|gv
# |t'ad
# |t'ou
# |t'eh
# |t'ee
# }}
#
# ==Mezquital Otomi==
#
# ===Etymology 1===
# From {{inh-lite|ote|oto-otm-pro|*ta}}, from {{inh-lite|ote|oto-pro|*ta}}.
#
# ====Pronunciation====
# * {{IPA-lite|ote|/tá/|/tà/}}
#
# ====Noun====
# {{head-lite|ote|nouns}}
#
# # {{l-lite|en|father}}
#
# =====Synonyms=====
# * {{l-lite|ote|dada}}
#
# ===Etymology 2===
#
# ====Pronunciation====
# * {{IPA-lite|ote|/tǎ/}}
#
# ====Noun====
# {{head|ote|noun|head=tǎ}}
#
# # a {{l-lite|en|male}} animal
# # an {{l-lite|en|intact}} {{gloss|not castrated}} male animal
#
# =====Derived terms=====
# {{col3|ote
# |tafri
# |tajä
# |takjä
# |tamxi
# |taꞌni
# |taꞌnxi
# |taptsꞌu̱di
# }}
#
# ==Mòcheno==
#
# ===Etymology===
# {{root|mhn|ine-pro|*dʰegʷʰ-}}
# From {{inh-lite|mhn|gmh|tag}}, from {{inh-lite|mhn|goh|tag}}, from {{inh-lite|mhn|gmw-pro|sc=Latn|*dag}}, from {{inh-lite|mhn|gem-pro|sc=Latn|*dagaz||day}}. Cognate with {{cog-lite|de|Tag}}, {{cog-lite|en|day}}.
#
# ===Noun===
# {{mhn-noun|m}}
#
# # [[day]]
#
# ====Related terms====
# {{col2|mhn
# |eirta
# |hait
# |ma'ta
# |mitta
# |mitto
# |Najorto
# |pfinsta
# |vraita
# |sònsta
# |sunta}}
#
# ===References===
# * {{R:CLM}}
#
# [[Category:mhn:Time]]
#
# ==North Moluccan Malay==
#
# ===Pronunciation===
# * {{IPA|max|/ta/}}
# * {{hmp|max|ta-}}
#
# ===Pronoun===
# {{head|max|pronoun}}
#
# # {{clip of|max|kita}}
#
# ==Norwegian Bokmål==
#
# ===Etymology===
# {{root|nb|ine-pro|*teh₂g-|id=touch}}
# From {{inh-lite|nb|non|taka}}, from {{inh-lite|nb|gem-pro|sc=Latn|*tēkaną||to touch}}.
#
# ===Pronunciation===
# * {{IPA-lite|nb|/tʰɑː/}}
# * {{audio|nb|no-ta.ogg}}
#
# ===Verb===
# {{head|nb|verb|imperative|ta|present tense|tar|passive|tas|simple past|tok|past participle|tatt}}
#
# # to [[take]] {{gloss|grab with the hands}}
# # to [[have]]
# #: {{ux-lite|inline=1|nb|'''ta''' en øl|have a beer}}
# # to [[do]]
# #: {{uxi|nb|Vi kan '''ta''' det senere.|We can '''do''' it later.}}
#
# ====Derived terms====
# {{col3|nb
# |anta
# |avta
# |[[avtagbar]], [[avtakbar]]
# |foreta
# |frata
# |frita
# |gjenta
# |godta
# |hærta
# |innta
# |ivareta
# |motta
# |oppta
# |overta
# |påta
# |påtatt
# |[[påtagelig]], [[påtakelig]]
# |ta knekken på
# |ta opp
# |ta på alvor
# |ta vare på
# |tiltak
# |unnta
# |vedta
# |voldta
# }}
#
# ===References===
# * {{R:The Bokmål Dictionary}}
#
# ==Norwegian Nynorsk==
#
# ===Etymology 1===
# {{root|nn|ine-pro|*teh₂g-|id=touch}}
# From earlier and {{inh-lite|nn|non|taka}}, from {{inh-lite|nn|gem-pro|sc=Latn|*tēkaną}}. Akin to {{cog-lite|en|take}}.
#
# ====Alternative forms====
# * {{alt|nn|taka||long form with a- or split infinitive}}
# * {{alt|nn|take||long form with e-infinitive}}
#
# ====Pronunciation====
# * {{IPA-lite|nn|/tɑː/}}
# * {{audio|nn|no-ta.ogg}}
#
# ====Verb====
# {{head|nn|verb|cat2=strong verbs|cat3=class 6 strong verbs|present tense|tek|or|tar|past tense|tok|supine|teke|or|tatt|past participle|teken|or|tatt|present participle|takande|passive infinitive|takast|imperative|ta}}
#
# # to {{l-lite|en|take}} (to grab with the hands)
# # to {{l-lite|en|catch}} (to capture)
#
# =====Derived terms=====
# {{col3|nn
# |anta
# |frita
# |hærta
# |oppta
# |påtatt
# |påteken
# |ta att
# |ta av
# |ta etter
# |ta for seg
# |ta fri
# |ta grep
# |ta i
# |ta imot
# |ta inn
# |ta knekken på
# |ta med
# |ta på
# |ta på alvor
# |ta på seg
# |ta seg
# |ta seg av
# |ta seg for
# |ta seg saman
# |ta seg ut
# |ta til
# |ta unna
# |ta ut
# |ta vare på
# |ta vekk
# |taking
# |vareta
# }}
#
# =====Related terms=====
# * {{l-lite|nn|tak}}
# * {{l-lite|nn|-tekt}}
#
# ===Etymology 2===
# Aasen, in his 1850 dictionary, lists it as a variant of {{m-lite|nn|ut-av}}.&lt;ref&gt;{{R:Aasen1850|ut-av}}&lt;/ref&gt; As such, the origin of this word is not to dissimilar from that of {{m-lite|nn|på||on}} from Old Norse {{m-lite|nn|upp á}}. Other variants include {{m-lite|nn|tå}}.
#
# ====Preposition====
# {{head-lite|nn|prepositions}}
#
# # {{lb|nn|dialectal}} {{alt form|nocap=1|nn|av}} ({{rfdef|nn}})
#
# ====Adverb====
# {{head-lite|nn|adverbs}}
#
# # {{lb|nn|dialectal}} [[off]]
# #* {{quote-book|nn|year=1953|author=Reidar Holtvedt|title=Historier fra Krokskauen|location=Oslo|publisher=Aschehoug|page=132|passage=Så hok dom, og strast føre berjhufsen hevde mann se '''ta''', [m]en kjelken reste beint utføre så det bare vart flisa att.|translation=They sledded, and right before the cliff, you'd throw yourself '''off''', but the sled raced straight down, so that there were only splinters left.}}
#
# ===References===
# {{reflist}}
# * {{R:ND}}
# * {{R:NO}}
#
# ===Anagrams===
# * {{l-lite|nn|at}}
#
# ==Old English==
#
# ===Alternative forms===
# * {{alter|ang|tahe}}
#
# ===Etymology===
# {{root|ang|ine-pro|*deyḱ-}}
# From {{inh-lite|ang|gmw-pro|*taihā}}, from {{inh-lite|ang|gem-pro|*taihwǭ}}.
#
# ===Pronunciation===
# * {{ang-IPA|tā}}
#
# ===Noun===
# {{ang-noun|head=tā|f|tān}}
#
# # {{lb|ang|anatomy}} [[toe]]
#
# ====Declension====
# {{ang-decl-noun-n-f|tā|vowel=1}}
#
# ====Descendants====
# * {{desc|enm|ta|to}}
# ** {{desc|en|toe}}
# ** {{desc|sco|tae}}
#
# ==Old French==
#
# ===Etymology===
# From {{inh-lite|fro|la|tua}}, feminine of {{m-lite|la|tuus}}.
#
# ===Determiner===
# {{head|fro|determiner|cat2=possessive determiners|g=f|masculine|ton|plural|tes}}
#
# # [[your]] (second-person singular possessive)
#
# ====Descendants====
# * {{desc|fr|ta}}
#
# ==Old Polish==
#
# ===Etymology===
# {{rfe|zlw-opl}} {{etydate|1430}}
#
# ===Pronunciation===
# * {{zlw-opl-IPA}}
#
# ===Particle===
# {{head|zlw-opl|particle}}
#
# # {{lb|zlw-opl|attested in|Greater Poland}} {{ng|emphatic particle}}
# #* {{RQ:zlw-opl:Pozn|1348|1430|Jszem czom wsąl troye cony, vosz y schekira, tom wsal w mego pąna v szapuscze, gdzyes '''ta''' nykt nye rabi, yedno czo v Brodi przedawa|Iżem com wziął troje koni, woz i siekirę, tom wziął u mego pana w zapuście, gdzież '''ta''' nikt nie rąbi, jedno co u Brody przedawa|-}}
#
# ====Descendants====
# * {{desc|pl|ta|id=emphatic particle}}
#
# ===References===
# * {{R:zlw-opl:SPJSP||17057}}
#
# ==Omaha-Ponca==
#
# ===Noun===
# {{head-lite|oma|nouns}}
#
# # [[jerky]], dried meat
#
# ===References===
# * [https://omahaponca.unl.edu/omaha/view/11490/ Omaha Ponca digital dictionary]
#
# ==Palauan==
# {{cardinalbox|pau|0|1|2|zero|eru}}
#
# ===Etymology===
# From Pre-Palauan ''*ta'', from {{inh-lite|pau|poz-pro|sc=Latn|*əsa}}, from {{inh-lite|pau|map-pro|sc=Latn|*əsa}}.
#
# ===Numeral===
# {{head-lite|pau|numerals}}
#
# # [[Category:Palauan cardinal numbers]] [[one]]
#
# ==Pali==
#
# ===Alternative forms===
# {{pi-alt}}
# {{pi-alt|Latn=sa}}
# {{pi-alt|Latn=so}}
#
# ===Etymology===
# {{dercat|pi|inc-pro|iir-pro|ine-pro|inh=3}}
# From {{inh|pi|sa|स}}, {{m|sa|तद्||this, that}}.
#
# ===Adjective===
# {{pi-adj}}
#
# # {{lb|pi|demonstrative}} [[that]]
# # [[that one]]
#
# ====Usage notes====
# The case form {{l-lite|pi|tad}} is only used before vowels and as the prefixed combining form.  {{m-lite|pi|taṃ}} is also used as the prefixed combing form.
#
# ====Declension====
# {{pi-decl-noun|g=m
# |novoc=true
# |noms_mod=replace|noms=so|noms2=sa
# |dats_mod=replace|dats=tassa
# |abls_mod=replace|abls=tasmā|abls2=tamhā|abls3=tato
# |locs_mod=replace|locs=tasmiṃ|locs2=tamhi
# |nomp_mod=replace|nomp=te
# |datp_mod=replace|datp=tesaṃ|datp2=tesānaṃ
# |genp_mod=replace|genp=tesaṃ|genp2=tesānaṃ
# }}
# {{pi-decl-noun|tā|g=f
# |novoc=true
# |noms_mod=replace|noms=sā
# |dats1=tassā|dats2=tissā|dats3=tissāya
# |gens1=tassā|gens2=tissā|gens3=tissāya
# |locs=tissaṃ
# |nomp_mod=replace|nomp=tā
# |accp_mod=replace|accp=tā
# |datp_mod=replace|datp=tāsaṃ|datp2=tāsānaṃ
# |genp_mod=replace|genp=tāsaṃ|genp2=tāsānaṃ
# }}
# {{pi-decl-noun|g=n
# |novoc=true
# |noms=tad|accs=tad
# |dats_mod=replace|dats=tassa
# |abls_mod=replace|abls=tasmā|abls2=tamhā|abls3=tato
# |locs_mod=replace|locs=tasmiṃ|locs2=tamhi
# |datp_mod=replace|datp=tesaṃ|datp2=tesānaṃ
# |genp_mod=replace|genp=tesaṃ|genp2=tesānaṃ
# }}
#
# ====Synonyms====
# * {{l-lite|pi|na}}
#
# ====Derived terms====
# * {{l-lite|pi|ta||he, it, that one}}
# * {{l-lite|pi|tā||she, it, that one}}
#
# ===Pronoun===
# {{pi-pronoun|m}}
#
# # he, it, that one
#
# ====Declension====
# {{pi-decl-noun|g=m
# |novoc=true
# |noms_mod=replace|noms=so|noms2=sa
# |dats_mod=replace|dats=tassa
# |abls_mod=replace|abls=tasmā|abls2=tamhā|abls3=tato
# |locs_mod=replace|locs=tasmiṃ|locs2=tamhi
# |nomp_mod=replace|nomp=te
# |datp_mod=replace|datp=tesaṃ|datp2=tesānaṃ
# |genp_mod=replace|genp=tesaṃ|genp2=tesānaṃ
# }}
#
# ===Pronoun===
# {{pi-pronoun|n}}
#
# # [[it]]
# #* {{RQ:pi:Anisongfree quote|1|bahum|18}}
#
# ====Usage notes====
# The case form {{l-lite|pi|tad}} is only used before vowels and as a prefixed combining form.  The form ending in niggahita is also used as combining form.
#
# ====Declension====
# {{pi-decl-noun|g=n
# |novoc=true
# |noms=tad|accs=tad
# |dats_mod=replace|dats=tassa
# |abls_mod=replace|abls=tasmā|abls2=tamhā|abls3=tato
# |locs_mod=replace|locs=tasmiṃ|locs2=tamhi
# |datp_mod=replace|datp=tesaṃ|datp2=tesānaṃ
# |genp_mod=replace|genp=tesaṃ|genp2=tesānaṃ
# }}
#
# ===References===
# {{R:pi:PTS|ta˚}}
#
# ==Papiamentu==
#
# ===Etymology===
# From {{der-lite|pap|es|estar}} and {{der-lite|pap|pt|estar}} and {{der-lite|pap|kea|sta}}.
#
# ===Verb===
# {{head-lite|pap|verbs}}
#
# # to [[be]]
# #: {{ux|pap|Papiamentu '''ta''' un idioma krioyo|t=Papiamentu '''is''' a creole language.}}
# #: {{ux|pap|Mi gusta e kas aki, pero e '''ta''' muchu karu.|t=I like this house, but it''''s''' too expensive.}}
# # to [[be]] {{gloss|auxiliary verb for the [[progressive]]/[[continuous]] [[aspect]], preceding the [[gerund]] of the verb}}
# #: {{ux|pap|Mi '''ta''' lesendo un buki.|t=I''''m''' reading a book.}}
#
# ===References===
# {{R:pap:Hoyer}}
#
# ==Phalura==
#
# ===Etymology===
# {{rfe-lite|phl}}
#
# ===Pronunciation===
# * {{IPA-lite|phl|/ta/}}
#
# ===Particle===
# {{head|phl|particle|discourse||Perso-Arabic spelling|تہ}}
#
# # Particle with different-subject marking function (variously corresponding to 'when, then, so (that), and')
#
# ===References===
# * {{R:phl:Liljegren:Vocab}}
#
# ==Phuthi==
#
# ===Etymology===
# From {{inh-lite|bnt-phu|bnt-pro|sc=Latn|*-jìja}}.
#
# ===Verb===
# {{bnt-phu-verb|ta}}
#
# # to [[come]]
#
# ====Inflection====
# {{rfinfl|bnt-phu|verb}}
#
# ==Polish==
#
# ===Pronunciation===
# {{pl-p|a=Pl-ta.ogg}}
#
# ===Etymology 1===
# Inherited from {{inh-lite|pl|sla-pro|sc=Latn|*ta}}, from {{der-lite|pl|ine-pro|sc=Latn|*só|*séh₂}}.
#
# ====Pronoun====
# {{head|pl|pronoun|g=f|cat2=demonstrative pronouns}}
#
# # [[this]] {{gl|nearby, feminine}}
#
# =====Declension=====
# {{pl-decl-noun
# |ta|te
# |tej|tych
# |tej|tym
# |tę|te
# |tą|tymi
# |tej|tych
# |–|–
# }}
#
# ====See also====
# * {{l-lite|pl|ten|g=m}}
# * {{l-lite|pl|to|g=n}}
#
# ===Etymology 2===
# {{clipping|pl|tak}}.
#
# ====Interjection====
# {{head|pl|interjection}}
#
# # {{lb|pl|colloquial}} [[yes]]
#
# ===Etymology 3===
# {{etymid|pl|conjunction}}
# Borrowed from {{bor-lite|pl|uk|sc=Cyrl|та|tr=ta}}.&lt;ref&gt;{{cite-journal|pl
# |author=Tadeusz Lehr
# |journal=Język Polski
# |issues=2-3
# |title=O mowie Polaków w Galicji wschodniej
# |url=http://mbc.malopolska.pl/dlibra/plain-content?id=18152
# |year=1914
# |page=50}}&lt;/ref&gt;
#
# ====Conjunction====
# {{head|pl|conjunction}}
#
# # {{lb|pl|regional}} [[and]]
# #: {{syn|pl|a|i}}
#
# ===Etymology 4===
# {{etymid|pl|emphatic particle}}
# Inherited from {{inh-lite|pl|zlw-opl|ta}}.
#
# ====Particle====
# {{head|pl|particle}}
#
# # {{lb|pl|regional|often attached to a verb}} {{ng|emphatic particle}}
# #: {{syn|pl|-ć|-ż|q1=not productive}}
#
# ===References===
# {{reflist}}
#
# ===Further reading===
# * {{R:pl:PWN}}
# * {{R:pl:SJP1807}}
# * {{R:pl:SJP1861}}
# * {{R:pl:SJP1900||1|7}}
# * {{R:pl:Bruckner}}
# * {{R:wsource|pl|M. Arcta Słownik Staropolski/Ta}}
#
# ==Portuguese==
#
# ===Pronunciation===
# {{pt-IPA}}
#
# ===Contraction===
# {{head|pt|contraction|g=f-s}}
#
# # {{contraction of|pt|[[te]] [[a]]||her/it to you {{q|familiar singular}}|nodot=1}}: {{infl of|pt|to||f}}
#
# ==Romanian==
#
# ===Etymology===
# From {{inh-lite|ro|VL.||*ta}}, from {{inh-lite|ro|la|tua}}, feminine of {{m-lite|la|tuus}}.
#
# ===Pronunciation===
# * {{IPA-lite|ro|/ta/}}
# * {{audio|ro|LL-Q7913 (ron)-Andreea Teodoraa-ta.wav}}
# * {{rhymes-lite|ro|a|s=1}}
#
# ===Determiner===
# {{head-lite|ro|determiner forms}}
#
# # {{inflection of|ro|tău||f|s|t=your}}
# #: {{ux|ro|Dani [[are]] [[carte]]a '''ta'''.|Dani has '''your''' book.}}
#
# ===Pronoun===
# {{head|ro|pronoun|g=f|possessive pronouns preceded by|a}}
#
# # [[yours]] (singular)
#
# ==Rotuman==
# {{cardinalbox|rtm|0|1|2||rua|ord=}}
#
# ===Etymology===
# From {{inh-lite|rtm|poz-oce-pro|-}}, from {{inh-lite|rtm|poz-pro|sc=Latn|*isa}}, {{m-lite|poz-pro|sc=Latn|*əsa}}, from {{inh-lite|rtm|map-pro|sc=Latn|*isa}}, {{m-lite|map-pro|sc=Latn|*əsa}}, {{m-lite|map-pro|sc=Latn|*asa}}.
#
# ===Numeral===
# {{head-lite|rtm|numerals|cat2=cardinal numbers}}
#
# # [[one]]
#
# ==San Pedro Amuzgos Amuzgo==
#
# ===Etymology 1===
#
# ====Pronunciation====
# * {{IPA-lite|azg|/tˠa̤˥˩/}}
#
# ====Noun====
# {{head-lite|azg|nouns}}
#
# # {{l-lite|en|grandfather}}
# # {{n-g-lite|A respectful title for a man.}}
#
# ===Etymology 2===
#
# ====Pronunciation====
# * {{IPA-lite|azg|/tˠa˥/}}
#
# ====Adjective====
# {{head-lite|azg|adjectives}}
#
# # full of {{l-lite|en|weeds}}
#
# ===Etymology 3===
#
# ====Pronunciation====
# * {{IPA-lite|azg|/tˠa̤˧/}}
#
# ====Adjective====
# {{head-lite|azg|adjectives}}
#
# # {{l-lite|en|thick}}
#
# ===Etymology 4===
#
# ====Pronunciation====
# * {{IPA-lite|azg|/tˠa̤˩/}}
#
# ====Noun====
# {{head|azg|noun|plural|nta}}
#
# # {{l-lite|en|fence}}, {{l-lite|en|wall}} {{gloss|of stakes, cane, or mud}}
#
# ===Etymology 5===
#
# ====Pronunciation====
# * {{IPA-lite|azg|/tˠa̤˩/}}
#
# ====Noun====
# {{head-lite|azg|nouns}}
#
# # {{l-lite|en|bunch}} {{gloss|of bananas}}
#
# ==Serbo-Croatian==
#
# ===Pronunciation===
# * {{IPA-lite|sh|/tâː/}}
#
# ===Pronoun===
# {{sh-pronoun|head=tȃ}}
#
# # {{inflection of|sh|taj||f|nom|s}}
# # {{inflection of|sh|taj||n|nom|p}}
# # {{inflection of|sh|taj||n|acc|p}}
#
# ==Slovene==
#
# ===Etymology===
# From {{inh-lite|sl|sla-pro|sc=Latn|*tъ}}.
#
# ===Pronunciation===
# * {{sl-IPA|tȃ}}
#
# ===Determiner===
# {{sl-det|tȃ}}
#
# # [[this]]
# # {{lb|sl|nonstandard}} [[the]] (definite article)
#
# ====Inflection====
# {{sl-decl-pron-ta}}
#
# {{catlangname|sl|demonstrative determiners}}
#
# ==Spanish==
#
# ===Interjection===
# {{head|es|interjection}}
#
# # {{lb|es|Uruguay}} {{alternative spelling of|es|tá||[[okay]]}}
#
# ===Further reading===
# * {{R:es:DRAE}}
#
# ==Sumerian==
#
# ===Romanization===
# {{sux-rom}}
#
# # {{romanization of|sux|𒋫|tr=ta}}
#
# ==Swazi==
#
# ===Etymology===
# From {{inh-lite|ss|bnt-pro|sc=Latn|*-jìja}}.
#
# ===Verb===
# {{ss-verb|ta}}
#
# # to [[come]]
#
# ====Inflection====
# {{rfinfl|ss|verb}}
#
# ====Related terms====
# * {{l-lite|ss|etama|-etama}}
#
# ==Swedish==
#
# ===Alternative forms===
# * {{l-lite|sv|taga}} {{qualifier|dated}}
#
# ===Etymology===
# {{root|sv|ine-pro|*teh₂g-|id=touch}}
# {{apocopic form of|sv|taga}}, from {{inh-lite|sv|gmq-osw|taka}}, from {{inh-lite|sv|non|taka}}, from {{inh-lite|sv|gem-pro|sc=Latn|*tēkaną}}. Cognate with {{cog-lite|en|take}}.
#
# ===Pronunciation===
# * {{IPA-lite|sv|/tɑː/}}
# * {{audio|sv|Sv-ta.ogg}}
#
# ===Verb===
# {{sv-verb-irr|tar|tog|tagit|ta}}
#
# # [[take]]; to grab and move to oneself
# #: {{ux-lite|sv|Han hade '''tagit''' kakan.|He had '''taken''' the cake.}}
# # to [[bring]] (along); to carry
# #: {{ux-lite|sv|'''Ta''' med kakan.|'''Bring''' the cake.}}
# # [[steal]]
# #: {{ux-lite|sv|Inbrottstjuven hade '''tagit''' allting.|The burglar had '''taken''' everything.}}
# # take; [[catch]]
# #: {{ux-lite|sv|Inbrottstjuven '''togs''' genast.|The burglar '''was caught''' immediately.}}
# # take (control over)
# #: {{ux-lite|sv|Kan du '''ta''' över?|Can you '''take''' over?}}
# # take; make use of
# #: {{ux-lite|sv|Karl '''tar''' cykeln till jobbet.|Karl '''is taking''' the bike to work.}}
# # take, [[pick]]; to [[choose]]
# #: {{ux-lite|sv|Vilket alternativ '''tar''' du?|Which option do you '''choose'''?}}
# # take; to manage; to be able to handle
# # take; to [[endure]]
# # take; to ingest a medicine or a drug
# #: {{ux-lite|sv|Patienten hade '''tagit''' allting.|The patient had '''taken''' everything.}}
# # take (a course); to [[enroll]]
# # take (a test)
# #: {{ux-lite|sv|Han hade '''tagit''' blodprovet.|He had '''taken''' the blood test.}}
# # take, [[capture]]; remove one of the opponent's pieces (e.g. in chess)
# # take; beat; be victorious
# #: {{ux-lite|sv|Idrottaren '''tog''' medalj.|The athlete '''took''' a medal.}}
# # {{lb|sv|reflexive}} to start burning; to go from embers into open flames
# #: {{ux-lite|sv|'''Tar''' elden sig?|Is the fire starting to burn?}}
# # {{lb|sv|reflexive}} {{qualifier|about a plant}} take; [[thrive]], [[persist]]
# # take; to have sex with forcefully
# #: {{ux-lite|sv|Han '''tog''' henne bakifrån.|He '''rammed''' her from behind.}}
# # [[accept]] (as means of payment)
# #: {{ux-lite|sv|'''Tar''' ni kort här?|Do you '''take''' credit cards?}}
# # take, to [[last]] (an amount of time)
# #: {{ux-lite|sv|Resan '''tar''' en timme.|The trip will '''take''' an hour.}}
# # {{lb|sv|followed by {{m|sv|och}} and a verb}} to [[do]], to get down to doing (something requiring some degree of decisiveness)
# #: {{ux|sv|Det ser ut som en svinstia här inne. Jag borde '''ta och städa'''.|It looks like a pigsty in here. I should '''do some cleaning up'''.}}
#
# ====Conjugation====
# {{sv-conj-st|class=6|ta|tog|tag|end=vw|full=taga}}
# {{sv-conj-st|class=6|head=taga|tag|tog|tag|end=s|note=dated}}
#
# ====Antonyms====
# * {{antsense|to grab}} {{l-lite|sv|ge}}
#
# ====Derived terms====
# {{der4|sv
# |avta
# |beslagta
# |bli tagen på sängen
# |fan ta dig
# |fan ta er
# |frita
# |förta
# |inta
# |omhänderta
# |satan ta dig
# |satan ta er
# |ta anställning
# |ta ansvar
# |ta av
# |ta av daga
# |ta av sig
# |ta avsked
# |ta avstånd
# |ta beslut
# |ta betalt
# |ta bort
# |ta det lugnt
# |ta emot
# |ta emot sig
# |ta examen
# |ta fart
# |ta farväl
# |ta fram
# |ta för givet
# |ta för sig
# |ta hand om
# |ta helst
# |ta hem
# |ta hus i helvete
# |ta hänsyn
# |ta i
# |ta ifrån
# |ta igen sig
# |ta in
# |ta initiativ
# |ta kort
# |ta livet av
# |ta lån
# |ta lätt på
# |ta med
# |ta musten ur någon
# |ta ned
# |ta ner
# |ta och
# |ta om
# |ta plats
# |ta på
# |ta på allvar
# |ta på bar gärning
# |ta på sig
# |ta på skoj
# |ta sats
# |ta sig an
# |ta sig fram
# |ta sig för
# |ta sig före
# |ta sig i arslet
# |ta sig i baken
# |ta sig i röven
# |ta sig igenom
# |ta sig in
# |ta sig samman
# |ta sig till
# |ta sig ton
# |ta sig upp
# |ta sig ur
# |ta sig ut
# |ta sig vatten över huvudet
# |ta sig över
# |ta sikte
# |ta sikte på
# |ta sitt förnuft till fånga
# |ta skydd
# |ta studenten
# |ta ställning
# |ta tag i
# |ta telefonen
# |ta tempen
# |ta tid på sig
# |ta tiden
# |ta till
# |ta till sig
# |ta tillvara
# |ta timeout
# |ta ton
# |ta upp
# |ta ut
# |ta ut i förskott
# |ta ut sig
# |ta vara på
# |ta vägen
# |ta åt sig
# |ta över
# |ta överbalansen
# |tillfångata
# |tillta
# |återta
# |överta
# }}
#
# ====Related terms====
# * {{l-lite|sv|tagning}}
#
# ===References===
# * {{R:svenska.se|so}}
# * {{R:svenska.se|saol}}
# * {{R:svenska.se|saob}}
#
# ===Anagrams===
# * {{anagrams|sv|a=at|AT}}
#
# ==Tagalog==
#
# ===Pronunciation===
# {{tl-pr}}
#
# ===Etymology 1===
# Influenced by Baybayin character {{m|tl|{{tl-bay sc|ta}}}}.
#
# ====Noun====
# {{tl-noun|b=+}}
#
# # {{tl-letter name|T|t|alph=abak}}
# #: {{syn-lite|tl|ti|te|q1=in the Filipino alphabet|q2=in the Abecedario}}
#
# =====See also=====
# {{col3|tl|tata}}
#
# ===Etymology 2===
# From {{inh-lite|tl|phi-pro|sc=Latn|*ta}}. Compare {{cog-lite|bcl|ta}}.
#
# ====Pronoun====
# {{tl-pron|b=+}}
#
# # {{lb|tl|archaic}} by both [[you]] and [[I]]; of both [[you]] and [[I]]
# #: {{syn|tl|natin|nata|nita}}
# #: {{ux-lite|tl|Bahay '''ta'''.|'''Our (two)''' house.}}
# #: {{ux-lite|tl|Hintayin '''ta''' muna.|Let '''us (two)''' wait first.}}
#
# ====See also====
# {{tl-personal pronouns}}
#
# ==Tooro==
#
# ===Pronunciation===
# * {{IPA|ttj|/ta/}}
#
# ===Adverb===
# {{head|ttj|adverb|head=-ta}}
#
# # {{lb|ttj|interrogative}} [[how]], in what [[manner]]
# #: {{uxi|ttj|Bakikora '''bata'''?|'''How''' do they do it?}}
# #* {{RQ:BRR2008|Luke|10|26||Yesu yamugarukamu ati: “Omu Biragiro kikahandiikwa '''kita'''? Osomamu '''ota'''?”|Jesus said to him, “'''What''' is written in the law? '''What''' do you understand from it?”|footer={{qlit|Jesus answered: ‘'''How''' was it written in the laws? '''How''' do you read in it?’}}}}
#
# ====Inflection====
# {{ttj-pers-decl-verb}}
#
# ===References===
# * {{R:ttj:Kaji:2007|page=428}}
#
# [[Category:Tooro interrogative adverbs]]
#
# ==Tsonga==
#
# ===Etymology===
# From {{inh-lite|ts|bnt-pro|sc=Latn|*-jìja}}.
#
# ===Verb===
# {{head-lite|ts|verbs}}
#
# # to [[come]]
#
# ==Turkish==
#
# ===Alternative forms===
# * {{alt|tr|te}}
#
# ===Etymology===
# {{inh+|tr|ota|تا|tr=tā}},&lt;ref&gt;{{R:ota:Redhouse|تا|page=470}}&lt;/ref&gt;&lt;ref&gt;{{R:ota:Kelekian|تا|page=333}}&lt;/ref&gt;&lt;ref&gt;{{R:ota:Sami:1899|369|تا}}&lt;/ref&gt; from {{bor|tr|fa|تا|tr=tâ|t=up to, until}}.&lt;ref&gt;{{R:tr:Nişanyan|ta}}&lt;/ref&gt;
#
# ===Pronunciation===
# * {{IPA|tr|/ˈta/}}
# * {{hyph|tr|ta}}
#
# ===Adverb===
# {{tr-adv}}
#
# # {{ng|Used with [[postposition]]s like {{m|tr|dek}}, {{m|tr|değin}}, {{m|tr|kadar}}, {{m|tr|beri}} etc. to emphasize the beginning or the end of a thing with regards to time or distance.}}
# #: {{uxi|tr|'''Ta''' sahile kadar koştu.|He ran all the way to the coast.}}
# #: {{uxi|tr|Burada '''ta''' 1'den beri seni bekliyorum.|I've been waiting for you here since 1.}}
# #: {{uxi|tr|Sınavdan geçmek için '''ta''' gündoğumuna kadar ders çalıştı.|She studied till sunrise to pass the exam.}}
#
# ===References===
# &lt;references/&gt;
#
# ===Further reading===
# * {{R:tr:TDK}}
# * {{R:tr:OTK|ta³|page=4511}}
#
# ==Unami==
#
# ===Etymology===
# Cognate with {{cog-lite|umu|taa|táa|emphatic}}.
#
# ===Particle===
# {{head-lite|unm|particles}}
#
# # [[indeed]], [[definitely]]
# adds emphasis to a statement or command.
#
# ===References===
# * {{R:unm:LTD|ta}}
#
# ==Uneapa==
#
# ===Etymology===
# From Proto-Western Oceanic ''*ta'', possibly from {{inh-lite|bbn|poz-oce-pro|sc=Latn|*ta}} (compare {{cog-lite|haw|ka}}).
#
# ===Pronunciation===
# * {{IPA-lite|bbn|/ta/}}
#
# ===Determiner===
# {{head-lite|bbn|determiners}}
#
# # [[the]] (indefinite)
#
# ===Further reading===
# * {{R:poz-oce:Ross 1988}}
#
# ==Vietnamese==
#
# ===Etymology===
# {{vi-etym-sino|咱|I; me, we; us|hv=n|cha}}.
#
# ===Pronunciation===
# {{vi-IPA}}
# * {{audio|vi|LL-Q9199 (vie)-Penn Zero MSSJ-ta.wav|a=Hanoi}}
#
# ===Adjective===
# {{vi-adj|[[些]], [[𢧲]], [[󱙐]]}}
#
# # {{lb|vi|informal}} &quot;[[our]]&quot;, [[Vietnamese]], as opposed to {{m-lite|vi|Tây||Western}}, {{m-lite|vi|Tàu||Chinese}} or {{m-lite|vi|Xiêm||Siamese}}
# #: {{ux-lite|vi|Tết '''ta'''|Vietnamese Lunar New Year|inline=1}}
#
# ===Pronoun===
# {{vi-pronoun|[[些]], [[𢧲]], [[󱙐]]}}
#
# # {{lb|vi|archaic|now|literary}} [[I]]; [[me]]
# #* {{quote-song|vi|author=lw:vi:Duy Mạnh|title=Kiếp đỏ đen|trans-title=Gambling Life|text='''Ta''' mang bao [[tội lỗi]],&lt;br&gt;Nên thân '''ta''' giờ đây,&lt;br&gt;Kiếp sống không nhà không người thân.&lt;br&gt;'''Ta''' mang bao tội lỗi,&lt;br&gt;Người ơi, '''ta''' đâu còn chi !&lt;br&gt;Xin hãy tránh xa kiếp đỏ đen !|t=I'm so sinful,&lt;br&gt;Now I have to live this life,&lt;br&gt;No home, no loved ones.&lt;br&gt;I'm so sinful,&lt;br&gt;O humanity, I have nothing left!&lt;br&gt;Please stay clear of the gambling life!}}
# # [[we]]; [[us]]
#
# ====Usage notes====
# * It might be a good idea to use ''ta'' to translate the English {{w|generic you}}. Also compare {{ncog-lite|fr|on||we/us; one; you}}.
# * {{m-lite|vi|ta||[[I]]; [[me]]}} is now only used especially in literary or translation works, to convey hostility between the characters, as alternatives (such as {{m-lite|vi|tao}}) may sound awkward or too rough, especially if the age difference between characters is significant (one translation, such as that of ''{{w|Beyblade}}'', may use ''tao'' for conversations between children of about the same age, but ''ta'' if there is such a difference). It is used in conjunction with {{m-lite|vi|mi|pos=informal}} or {{m-lite|vi|ngươi|pos=formal}} for &quot;you&quot;.
#
# ====Synonyms====
# * {{l-lite|vi|tôi}}; {{l-lite|vi|tui}}
# * {{l-lite|vi|min}}
# * {{l-lite|vi|tao}}; {{l-lite|vi|tau}}
#
# ====See also====
# * {{l-lite|vi|ngươi}}; {{l-lite|vi|mi||[[you]]}}
# * {{l-lite|vi|mình||[[I]]; [[me]]; [[we]]; [[us]]}}
# {{vi-der|chúng ta|ta đây}}
#
# ===Particle===
# {{vi-particle|[[些]], [[𢧲]], [[󱙐]]}}
#
# # {{lb|vi|colloquial|informal}} {{n-g|[[final]] [[particle]] used to [[reinforce]] a question, to express [[surprise]], or to indicate [[Appendix:Glossary#familiar|familiarity]] with whom the person is speaking with}}
# #: {{syn|vi|vậy|thế|rứa}}
# #: {{ux|vi|Sao kì vậy '''ta'''?|Why so strange? / What's wrong with '''you'''?}}
# #: {{ux|vi|Ông già quê ở đâu '''ta'''?|Where is your hometown, old man?}}
# #: {{ux|vi|Giỏi quá '''ta'''!|Good job, '''you'''!}}
#
# {{cln|vi|first person pronouns|personal pronouns}}
#
# ==Volapük==
#
# ===Pronunciation===
# * {{IPA-lite|vo|/ta/}}
#
# ===Preposition===
# {{head-lite|vo|prepositions}}
#
# # [[against]], [[opposed]] to, [[contrary]] to
#
# ====Derived terms====
# * {{l-lite|vo|taan}}
#
# ==Welsh==
#
# ===Pronunciation===
# * {{IPA|cy|/ta/}}
#
# ===Etymology 1===
# Ultimately from {{m|cy|bynnag||-ever}}. Initially, {{m|cy|bynnag}} began preceding rather than following the word it qualfied, for example, {{m|cy|beth bynnag||whatever}} became {{m|cy|bynnag}} {{m|cy|beth}}.  The initial {{m|cy|g}} of {{m|cy|bynnag}} was [[velarize|velarised]] to produce {{m|cy|gynnag}} {{m|cy|beth}}, whereupon the word was reanalysed as the phrase {{m|cy|gan}} {{m|cy|nag}}, a southern colloquial form of {{m|cy|gan}} {{m|cy|nad}}, literally &quot;since (that) not&quot;. The apparent inconsistency of negative {{m|cy|nag}} being a part of a phrase with no negative connotations led its replacement with corresponding affirmative {{m|cy|taw||that}}, so {{m|cy|gan}} {{m|cy|nag}} {{m|cy|beth}} became {{m|cy|gan}} {{m|cy|taw}} {{m|cy|beth}}. The initial {{m|cy|gan}} was subsequently dropped and the pronunciation of {{m|cy|taw}} /tau̯/ reduced to {{m|cy|ta}} /ta/, as is customary, leading to such forms as {{m|cy|ta beth||whatever}} today.&lt;ref&gt;{{R:cy:GPC}}&lt;/ref&gt;
#
# ====Particle====
# {{head-lite|cy|particles}}
#
# # {{a|cy|cy-S|informal}} {{l|en|ever|-ever}} {{ngd|precedes interrogative pronouns to form indefinite pronouns}}
# #: {{syn|cy|bynnag}}
#
# =====Derived terms=====
# * {{l|cy|ta beth||whatever}}
# * {{l|cy|ta ble||wherever}}
# * {{l|cy|ta faint||however many}}
# * {{l|cy|ta pryd||whenever}}
# * {{l|cy|ta pwy||whoever, whomever}}
#
# ===Etymology 2===
# {{clipping|cy|petai||if it were}}, itself a combination of {{com|cy|pe|t1=if|tai|t2={{ngd|third-person singular counterfactual impferfect subjunctive of {{m|cy|bod||to be}}}}}}.
#
# ====Conjunction====
# {{head|cy|conjunction}}
#
# # [[if]] it [[were]]
#
# =====Usage notes=====
# * Found in the phrase {{m|cy|ta waeth||anyway, however|lit=if it were worse}}.
#
# =====Derived terms=====
# * {{l|cy|ta waeth||anyway, however}}
#
# ===References===
# {{reflist}}
#
# ==West Frisian==
#
# ===Pronunciation===
# * {{IPA-lite|fy|/ta/}}
#
# ===Etymology 1===
# From {{inh-lite|fy|ofs|to}}, from {{inh-lite|fy|gem-pro|sc=Latn|*tō}}.
#
# ====Preposition====
# {{head-lite|fy|prepositions}}
#
# # {{lb|fy|with {{m-lite|fy|nei}}}} [[to]]
# # {{lb|fy|physically}} up to, until
#
# =====Further reading=====
# * {{R:WFT|101223}}
#
# ===Etymology 2===
# {{rfe-lite|fy}}
#
# ====Adjective====
# {{head-lite|fy|adjectives}}
#
# # [[closed]], [[shut]]
#
# =====Inflection=====
# {{rfinfl|fy|adjective}}
#
# =====Further reading=====
# * {{R:WFT|101223}}
#
# ==Wutunhua==
#
# ===Pronunciation===
# * {{IPA-lite|wuh|[tʰɑ]}}
#
# ===Etymology 1===
# From {{der-lite|wuh|cmn|-}} {{zh-l|他|tr=-}}.
#
# ====Pronoun====
# {{head-lite|wuh|pronouns}}
#
# # {{lb|wuh|apparently|_|uncommon}} [[he]], [[she]], [[it]] {{gloss|chiefly used in [[reported]] speech}}
#
# =====Usage notes=====
# {{m-lite|wuh|gu}} is the usual third-person pronoun in Wutunhua, and not the conventional Mandarin {{m-lite|wuh|ta}}.
#
# ===Etymology 2===
# From {{bor-lite|wuh|bo|sc=Tibt|ཐལ|tr=thal}}, as in {{m-lite|bo|sc=Tibt|གོ་ཐལ|tr=go thal}}.
#
# ====Noun====
# {{head-lite|wuh|nouns}}
#
# # [[ash]]es
#
# ===References===
# {{R:wuh:Janhunen}}
# {{R:wuh:Sandman}}
#
# ==Yola==
#
# ===Alternative forms===
# * {{alter|yol|to|t'}}
#
# ===Etymology===
# From {{inh-lite|yol|enm|to|ta, to}}, from {{inh-lite|yol|ang|to|tō}}, {{m-lite|ang|ta}}.
#
# ===Pronunciation===
# * {{IPA|yol|/tuː/|/tə/|/t/}}
#
# ===Preposition===
# {{head-lite|yol|prepositions}}
#
# # [[to]]
# #* {{quote-book|yol|year=1867|chapter=VERSES IN ANSWER TO THE WEDDEEN O BALLYMORE|number=1|page=100|title=SONGS, ETC. IN THE DIALECT OF FORTH AND BARGY|passage=A laafe ing lemethès chote wel '''ta''' ba zang,|translation=A leaf in tatters, I know well '''to''' be sung,}}
# #* {{quote-book|yol|year=1867|chapter=VERSES IN ANSWER TO THE WEDDEEN O BALLYMORE|number=3|page=100|title=SONGS, ETC. IN THE DIALECT OF FORTH AND BARGY|passage=At ye mye ne'er be wooveless '''ta''' vill a lear jock an cooan.|translation=That you may never be unprovided '''to''' fill an empty jack and can.}}
#
# ====Derived terms====
# {{col4
# |yol|t'glade
# |t'drive
# |t'yie
# |t'rapple
# |t'zey
# |to's
# |t'uck
# |t'gie
# |t'ouz
# |t'avance
# |t'oure
# }}
#
# ===References===
# * {{R:Poole 1867|page=71}}
#
# ==Yoruba==
#
# ===Etymology 1===
# From {{inh|yo|alv-yor-pro|*tà}}, from {{inh|yo|alv-edk-pro|*tà}}, ultimately from {{inh|yo|alv-yrd-pro|*tà}}. Compare with {{cog|igl|tà}}, {{cog|its|tà}}
#
# ====Pronunciation====
# * {{yo-IPA|tà}}
#
# ====Verb====
# {{yo-verb|tà}}
#
# # {{lb|yo|transitive|intransitive}} to [[sell]] [[something]]
# #: {{ux-lite|inline=1|yo|kí l'a à bá '''tà''' k'á fi ra ọmọ?|what could we possibly have '''sold''' to purchase a child?}} ''(proverb on the pricelessness of a child)''
#
# =====Usage notes=====
# * '''ta''' before a direct object
#
# =====Derived terms=====
# * {{l-lite|yo|ita|ìtà|selling}}
#
# ===Etymology 2===
#
# ====Pronunciation====
# * {{yo-IPA|ta}}
#
# ====Verb====
# {{yo-verb|ta}}
#
# # to [[grow]], to [[form]], to become [[big]]
# #: {{ux-lite|inline=1|yo|uṣu '''ta''', kí uṣu ò '''ta''', ọkọọkan ló gbéṣu àbá mi láti oko rẹ l'Éjìgbò|If the yam '''grows big''' or not, they must carry the yams of my father one by one from his farm in Ejigbo}} ''(family oríkì)''
# # to [[oppose]] or [[refuse]] something loudly
#
# =====Usage notes=====
# * Usually a stative verb, often used in referencing to [[tubers]] (yams, potatoes).
#
# =====Derived terms=====
# * {{l-lite|yo|taapa|tàápa|to form a scab}}
#
# ===Etymology 3===
#
# ====Pronunciation====
# * {{yo-IPA|ta}}
#
# ====Verb====
# {{yo-verb|ta}}
#
# # {{lb|yo|transitive}} to [[splash]], [[pop]], [[explode]]
# #: {{ux-lite|inline=1|yo|gúgúrú '''ta'''|The '''popcorn''' popped on the stove}}
# # to [[oppose]] or [[refuse]] something loudly
# #: {{ux-lite|inline=1|yo|ìgbìmọ̀ alátakòó '''ta''' lórí ọ̀rọ̀ náà|The opposition '''opposed''' the measure very loudly}}
#
# =====Usage notes=====
# * Usually a stative verb
#
# ===Etymology 4===
#
# ====Pronunciation====
# * {{yo-IPA|ta}}
#
# ====Verb====
# {{yo-verb|ta}}
#
# # {{lb|yo|intransitive}} to [[spring]], [[burst]], [[bounce]]
#
# =====Derived terms=====
# * {{l-lite|yo|tabọn-un|tabọ̀n-ùn|to bounce off swiftly}}
#
# ===Etymology 5===
#
# ====Pronunciation====
# * {{yo-IPA|ta}}
#
# ====Verb====
# {{yo-verb|ta}}
#
# # {{lb|yo|intransitive|copulative}} to [[shine]] (as in the sun or daylight)
# #: {{ux-lite|inline=1|yo|oòrún '''ta''' sí wá lára|The has '''shined''' on us}}
#
# =====Derived terms=====
# * {{l-lite|yo|iyalẹta|ìyálẹ̀ta|noon}}
#
# ===Etymology 6===
#
# ====Pronunciation====
# * {{yo-IPA|ta}}
#
# ====Verb====
# {{yo-verb|ta}}
#
# # {{lb|yo|transitive}} to [[shoot]], [[fire]] (from a [[weapon]] that releases a [[projectile]]).
# #: {{ux-lite|inline=1|yo|ọlọ́pàá '''ta''' ìbọn|The police officer '''fired''' his gun}}
# # {{lb|yo|transitive|of an insect or arachnid}} to [[sting]]
# #: {{ux-lite|inline=1|yo|oyín '''ta''' wọ́n|The bee '''stung''' them}}
# # {{lb|yo|transitive}} to be [[spicy]], to be [[hot]]
# #: {{ux-lite|inline=1|yo|atá '''ta'''|The pepper was '''spicy'''}}
# # {{lb|yo|transitive}} to [[kick]]
# #: {{ux-lite|inline=1|yo|ẹṣín '''ta''', ta, ta, ó kú o!|The horse '''kicked''', kicked, and kicked, and then it died}}
# # {{lb|yo|transitive}} to [[pick]], [[pluck]], [[floss]] (as in your teeth)
# #: {{ux-lite|inline=1|yo|ó ń fi wá '''ta'''yín|He was using us to '''floss his teeth''' - Literally, &quot;He was deliberately ignoring us at work&quot;}}
#
# =====Derived terms=====
# {{der3|yo
# |{{l-lite|yo|tafa|tafà|to shoot an arrow}}
# |{{l-lite|yo|ọta||bullet}}
# |{{l-lite|yo|ita|ìta|stinger}}
# |{{l-lite|yo|tanipaa|tanípàá|to kick}}
# |{{l-lite|yo|tapa|tàpá}}
# |{{l-lite|yo|ata||pepper}}
# |{{l-lite|yo|tabọn|tàbọn|to shoot a gun}}
# }}
#
# ===Etymology 7===
# Most dialects have a different cognate form, see Ekiti {{l-lite|yo|i si|ì sí}}, Ondo {{l-lite|yo|e si|è sí}}, Ẹ̀gbá &amp; Ìjẹ̀bú {{l-lite|yo|le si|lè sí}}, Ijesha {{l-lite|yo|ye si|yè sí}}, Iyagba {{l-lite|yo|ne ghi|nè ghí}}. See other Yoruboid languages {{cog-lite|its|nè sín}}, {{cog-lite|ulb|è ghí}}, {{cog-lite|ijj|lè é}}. Likely an innovation among the speakers of the {{l-lite|yo|Ọyọ|Ọ̀yọ́}} dialect of Yoruba, in which the modern Yoruba koine was constructed from.
#
# ====Pronunciation====
# * {{yo-IPA|ta}}
#
# ====Pronoun====
# {{yo-pos|pronoun|ta}}
#
# # {{lb|yo|interrogative}} [[who]], [[whom]], [[whose]]
# #: {{syn|yo|ì sí|q=Ekiti}}
# #: {{ux-lite|inline=1|yo|'''ta''' ni eṣinṣin kò bá gbè fún bí kò ṣe elégbò?|who else would a fly have sided with other than the one with an open sore or ulcer?}} ''(proverb on partiality)''
#
# =====Usage notes=====
# * An information-seeking question word for the human entity which is always followed by '''ni'''
#
# =====Synonyms=====
# &lt;div class=&quot;NavFrame&quot; style=&quot;width:350px&quot;&gt;
# &lt;div class=&quot;NavHead&quot; style=&quot;text-align: left&quot;&gt;'''Yoruba varieties (who, whom, whose)'''&lt;/div&gt;
# &lt;div class=&quot;NavContent&quot;&gt;
# {| class=&quot;wikitable&quot; border=&quot;1&quot; style=&quot;text-align: center&quot;
# ! style=&quot;width:11%&quot; | Language Family
# ! style=&quot;width:11%&quot; | Variety Group
# ! style=&quot;width:11%&quot; | Variety
# ! style=&quot;width:11%&quot; | Words
# |-
# | rowspan=&quot;6&quot; | '''Proto-Itsekiri-SEY'''
# | style=&quot;background: AliceBlue&quot;  rowspan=&quot;6&quot; | '''Southeast Yoruba'''
# | style=&quot;background: AliceBlue&quot;  | '''[[Ijẹbu|Ìjẹ̀bú]]'''
# | style=&quot;background: AliceBlue&quot;  | {{l-self|yo|lè sí}}
# |-
# | style=&quot;background: AliceBlue&quot;  | '''[[Ikalẹ|Ìkálẹ̀]]'''
# | style=&quot;background: AliceBlue&quot;  | {{l-self|yo|nẹ̀ẹ́}}, {{l-self|yo|nẹ̀ẹ́ sí}}
# |-
# | style=&quot;background: AliceBlue&quot;  | '''[[Ilajẹ|Ìlàjẹ]]'''
# | style=&quot;background: AliceBlue&quot;  | -
# |-
# | style=&quot;background: AliceBlue&quot;  | '''[[Ondo|Oǹdó]]'''
# | style=&quot;background: AliceBlue&quot;  | {{l-self|yo|è sí}}
# |-
# | style=&quot;background: AliceBlue&quot;  | '''[[Ọwọ|Ọ̀wọ̀]]'''
# | style=&quot;background: AliceBlue&quot;  | {{l-self|yo|sí}}
# |-
# | style=&quot;background: AliceBlue&quot;  | '''[[Usẹn|Usẹn]]'''
# | style=&quot;background: AliceBlue&quot;  | -
# |-
# | rowspan=&quot;23&quot; | '''Proto-Yoruba'''
# | style=&quot;background: Honeydew&quot;  rowspan=&quot;5&quot; | '''Central Yoruba'''
# | style=&quot;background: Honeydew&quot; | '''[[Ekiti|Èkìtì]]'''
# | style=&quot;background: Honeydew&quot; | {{l-self|yo|ì sí}}
# |-
# | style=&quot;background: Honeydew&quot; | '''[[Ifẹ|Ifẹ̀]]'''
# | style=&quot;background: Honeydew&quot; | -
# |-
# | style=&quot;background: Honeydew&quot; | '''[[Igbomina|Ìgbómìnà]]'''
# | style=&quot;background: Honeydew&quot; | -
# |-
# | style=&quot;background: Honeydew&quot; | '''[[Ijẹṣa|Ìjẹ̀ṣà]]'''
# | style=&quot;background: Honeydew&quot; | {{l-self|yo|yè sí}}
# |-
# | style=&quot;background: Honeydew&quot; | '''[[Akoko|Western Àkókó]]'''
# | style=&quot;background: Honeydew&quot; | -
# |-
# | style=&quot;background: Ivory&quot; rowspan=&quot;6&quot; | '''Northwest Yoruba'''
# | style=&quot;background: Ivory&quot; | '''[[Awori|Àwórì]]'''
# | style=&quot;background: Ivory&quot; | -
# |-
# | style=&quot;background: Ivory&quot; | '''[[Ẹgba|Ẹ̀gbá]]'''
# | style=&quot;background: Ivory&quot; | {{l-self|yo|lè sí}}
# |-
# | style=&quot;background: Ivory&quot; | '''[[Ibadan|Ìbàdàn]]'''
# | style=&quot;background: Ivory&quot; | {{l-self|yo|ta}} ni
# |-
# | style=&quot;background: Ivory&quot; | '''[[Onko|Òǹkò]]'''
# | style=&quot;background: Ivory&quot; | -
# |-
# | style=&quot;background: Ivory&quot; | '''[[Ọyọ|Ọ̀yọ́]]'''
# | style=&quot;background: Ivory&quot; | {{l-self|yo|ta}} ni
# |-
# | style=&quot;background: Ivory&quot; | '''Standard [[Yoruba|Yorùbá]]'''
# | style=&quot;background: Ivory&quot; | {{l-self|yo|ta}} ni
# |-
# | style=&quot;background: OldLace&quot; rowspan=&quot;5&quot; | '''Northeast Yoruba/[[Okun]]'''
# | style=&quot;background: OldLace&quot; | '''[[Ibunu|Ìbùnú]]'''
# | style=&quot;background: OldLace&quot; | -
# |-
# | style=&quot;background: OldLace&quot; | '''[[Ijumu|Ìjùmú]]'''
# | style=&quot;background: OldLace&quot; | -
# |-
# | style=&quot;background: OldLace&quot; | '''[[Iyagba|Ìyàgbà]]'''
# | style=&quot;background: OldLace&quot; | {{l-self|yo|nè ghí}}
# |-
# | style=&quot;background: OldLace&quot; | '''[[Owe|Owé]]'''
# | style=&quot;background: OldLace&quot; | {{l-self|yo|láun}}, {{l-self|yo|la}}, {{l-self|yo|lẹ}}
# |-
# | style=&quot;background: OldLace&quot; | '''[[Ọwọrọ|Ọ̀wọ̀rọ̀]]'''
# | style=&quot;background: OldLace&quot; | -
# |-
# |}
# &lt;/div&gt;&lt;/div&gt;
#
# ===Etymology 8===
#
# ====Pronunciation====
# * {{yo-IPA|ta}}
#
# ====Verb====
# {{yo-verb|ta}}
#
# # to [[stick out]] [[visibly]], to [[protrude]]
# #: {{ux-lite|inline=1|yo|eyín '''ta''' síta|The '''tooth''' stuck out}}
#
# ===Etymology 9===
#
# ====Pronunciation====
# * {{yo-IPA|ta}}
#
# ====Verb====
# {{yo-verb|ta}}
#
# # {{lb|yo|ergative}} to [[spin]] something, to [[roll]]
# #: {{ux-lite|inline=1|yo|ó '''ta''' òkòtó|She '''spun''' the spinning top}}
#
# =====Usage notes=====
# * Usually a stative verb
#
# ===Etymology 10===
#
# ====Pronunciation====
# * {{yo-IPA|ta}}
#
# ====Verb====
# {{yo-verb|ta}}
#
# # to [[snatch]] (suddenly)
# #: {{ux-lite|inline=1|yo|àṣá idìí '''ta''' òròmọdìẹ nílẹ̀|The hawk '''snatch''' a chick from the ground}}
#
# ===Etymology 11===
#
# ====Pronunciation====
# * {{yo-IPA|ta}}
#
# ====Verb====
# {{yo-verb|ta}}
#
# # to [[flirt]], to talk with teasing [[affection]]
# #: {{syn|yo|tage}}
# #: {{ux-lite|inline=1|yo|àwọn ọmọkùnrin àti ọmọbìnrin ń '''ta'''ge|The young boys and girls were '''flirting''' with each other}}
#
# ==Zou==
#
# ===Pronunciation===
# * {{IPA-lite|zom|/ta˧/}}
#
# ===Adjective===
# {{head-lite|zom|adjectives}}
#
# # [[hard]]
#
# ===References===
# * {{R:zom:Singh:2013|page=44}}</text>
#       <sha1>tjcuvgg9n8jkk100f7u44nzwjm08w13</sha1>
#     </revision>
#   </page>

# %%
tags = set()
for section in get_language_sections(article):
    # print(section)
    for tag in get_tags_from_section(section):
        tags.add(tag)
    if '==English==' in section:
        break
for tag in tags:
    print(tag)
# Out:
# ('Symbol', '{{mul-symbol}}\n\n# {{ISO 639|1}}')
# ('Etymology 1', "{{unc|en}}, but possibly young child's pronunciation of {{m-lite|en|thanks}}&lt;ref&gt;{{R:OED Online|code=196719|date=1989}}&lt;/ref&gt;&lt;ref&gt;&quot;[https://en.oxforddictionaries.com/definition/ta?locale=en ta]&quot; in Oxford Living Dictionaries&lt;/ref&gt; or an acronym for 'thanks a lot'.\n\nAlternatively, derived from {{bor-lite|en|da|tak}}, from {{der-lite|en|non|þǫkk}}, from {{der-lite|en|gem-pro|sc=Latn|*þankō}}, {{m-lite|gem-pro|sc=Latn|*þankaz}}.")
# ('Alternative forms', '* {{l-lite|en|taa}}')
# ('Pronunciation', '* {{IPA-lite|en|/tɑː/|[tʰɑː]}}\n* {{audio|en|en-au-ta.ogg|a=AU}}\n* {{rhymes-lite|en|ɑː|s=1}}')
# ('Interjection', "{{en-interj}}\n\n# {{lb|en|colloquial|chiefly|Commonwealth}} [[thanks|Thanks]].\n#: {{ux-lite|en|'''Ta''' for the cup of tea.}}\n# {{lb|en|Canada|baby talk}} [[give]] (imperative)\n#: {{ux-lite|en|Mommy needs the bottle back. '''Ta'''!}}")
# ('Usage notes', "The expression ''[[ta ta]]'' differs, meaning ''[[goodbye]]''.")
# ('Translations', '{{trans-see|thanks}}')
# ('See also', '* {{l-lite|en|ta everso}}\n* {{l-lite|en|ta muchly}}')
# ('Pronunciation', '* {{IPA-lite|en|/tə/}}')
# ('Preposition', "{{en-preposition}}\n\n# {{pronunciation spelling of|en|to|nodot=1}}'', representing the standard unstressed pronunciation before consonants.''")
# ('Etymology 3', "Altered from ''[[si]]'' in the 19th century to prevent having two notes of the musical scale starting with the same letter, to become ''[[ti]]''. vowel changed to 'a' to signify a flattened note.")
# ('Pronunciation', '* {{IPA-lite|en|/tɑː/}}\n* {{audio|en|en-au-ta.ogg|a=AU}}\n* {{rhymes-lite|en|ɑː|s=1}}')
# ('Noun', '{{en-noun|-}}\n\n# {{lb|en|music}} In [[solfège]], the lowered seventh note of a major scale (the note [[B-flat]] in the [[fixed-do]] system): [[te]].\n#: {{syn|en|te|B-flat|li}}')
# ('See also', '{{col2|en|pok-ta-pok|ta-da|Yah-ta-hey}}')
# ('References', '{{reflist}}')
# ('Anagrams', "* {{anagrams|en|a=at|'at|A-T|A/T|AT|at|at-}}")
# ('Pronunciation', '* {{IPA-lite|en|/tə/}}')
# ('Interjection', "{{en-interj}}\n\n# {{lb|en|colloquial|chiefly|Commonwealth}} [[thanks|Thanks]].\n#: {{ux-lite|en|'''Ta''' for the cup of tea.}}\n# {{lb|en|Canada|baby talk}} [[give]] (imperative)\n#: {{ux-lite|en|Mommy needs the bottle back. '''Ta'''!}}")
# ('Noun', '{{en-noun|-}}\n\n# {{lb|en|music}} In [[solfège]], the lowered seventh note of a major scale (the note [[B-flat]] in the [[fixed-do]] system): [[te]].\n#: {{syn|en|te|B-flat|li}}')
# ('Etymology 3', "Altered from ''[[si]]'' in the 19th century to prevent having two notes of the musical scale starting with the same letter, to become ''[[ti]]''. vowel changed to 'a' to signify a flattened note.")
# ('See also', '{{col2|en|pok-ta-pok|ta-da|Yah-ta-hey}}')
# ('References', '{{reflist}}')
# ('Translations', '{{trans-see|thanks}}')
# ('Etymology 1', "{{unc|en}}, but possibly young child's pronunciation of {{m-lite|en|thanks}}&lt;ref&gt;{{R:OED Online|code=196719|date=1989}}&lt;/ref&gt;&lt;ref&gt;&quot;[https://en.oxforddictionaries.com/definition/ta?locale=en ta]&quot; in Oxford Living Dictionaries&lt;/ref&gt; or an acronym for 'thanks a lot'.\n\nAlternatively, derived from {{bor-lite|en|da|tak}}, from {{der-lite|en|non|þǫkk}}, from {{der-lite|en|gem-pro|sc=Latn|*þankō}}, {{m-lite|gem-pro|sc=Latn|*þankaz}}.")
# ('Pronunciation', '* {{IPA-lite|en|/tɑː/|[tʰɑː]}}\n* {{audio|en|en-au-ta.ogg|a=AU}}\n* {{rhymes-lite|en|ɑː|s=1}}')
# ('Anagrams', "* {{anagrams|en|a=at|'at|A-T|A/T|AT|at|at-}}")
# ('Preposition', "{{en-preposition}}\n\n# {{pronunciation spelling of|en|to|nodot=1}}'', representing the standard unstressed pronunciation before consonants.''")
# ('Symbol', '{{mul-symbol}}\n\n# {{ISO 639|1}}')
# ('Usage notes', "The expression ''[[ta ta]]'' differs, meaning ''[[goodbye]]''.")
# ('Alternative forms', '* {{l-lite|en|taa}}')
# ('Pronunciation', '* {{IPA-lite|en|/tɑː/}}\n* {{audio|en|en-au-ta.ogg|a=AU}}\n* {{rhymes-lite|en|ɑː|s=1}}')
# ('See also', '* {{l-lite|en|ta everso}}\n* {{l-lite|en|ta muchly}}')
